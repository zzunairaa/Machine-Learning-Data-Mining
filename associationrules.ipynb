# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import warnings
warnings.filterwarnings('ignore')

# %%
url = "/content/Online-Retail-France.xlsx"

# %%
df0 = pd.read_excel(url)

# %%
df0.head(50)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 1     536370     22727            ALARM CLOCK BAKELIKE RED         24
# 2     536370     22726           ALARM CLOCK BAKELIKE GREEN        12
# 3     536370     21724      PANDA AND BUNNIES STICKER SHEET        12
# 4     536370     21883                     STARS GIFT TAPE         24
# 5     536370     10002          INFLATABLE POLITICAL GLOBE         48
# 6     536370     21791   VINTAGE HEADS AND TAILS CARD GAME         24
# 7     536370     21035      SET/2 RED RETROSPOT TEA TOWELS         18
# 8     536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND         24
# 9     536370     22629                  SPACEBOY LUNCH BOX         24
# 10    536370     22659              LUNCH BOX I LOVE LONDON        24
# 11    536370     22631             CIRCUS PARADE LUNCH BOX         24
# ...

# %%
print("the dataset has {} number of rows and {} number of columns".format(df0.shape[0], df0.shape[1]))
# Out:
# the dataset has 8557 number of rows and 7 number of columns

# %%
print("the number of unique description values are" , df0['Description'].nunique())
# Out:
# the number of unique description values are 1565

# %%
df1 = df0.copy()
df1['Description'] = df0['Description'].str.strip()
print("the number of unique description values after cleaning is" , df1['Description'].nunique())
# Out:
# the number of unique description values after cleaning is 1564

# %%
print("Number of rows not having InvoiceNo" , df1['InvoiceNo'].isna().sum())
# Out:
# Number of rows not having InvoiceNo 0

# %%
df2 = df1.copy()
df2= df2.dropna(axis =0 , subset =['InvoiceNo'])
print("Number of rows after cleaning " , df2['InvoiceNo'].isna().sum())
# Out:
# Number of rows after cleaning  0

# %%
print("the number of total transactions are" , df2['InvoiceNo'].count())
# Out:
# the number of total transactions are 8557

# %%
print("the number of credit transaction are" , df2['InvoiceNo'].str.contains('C').sum())
# Out:
# the number of credit transaction are 149

# %%
df3 = df2.copy()
df3['InvoiceNo'] = df3['InvoiceNo'].astype('str')
df3= df3[~df3['InvoiceNo'].str.contains('C')]
print("The number of rows after cleaning creidt transaction in InvoiceNo column are" , df3['InvoiceNo'].shape[0])
# Out:
# The number of rows after cleaning creidt transaction in InvoiceNo column are 8408

# %%
print("The total number of POSTAGE Values are" , df3.shape[0])
# Out:
# The total number of POSTAGE Values are 8408

# %%
df = df3[~df3['Description'].str.contains('POSTAGE' , na=False)]

# %%
print("The total number of rows are" , df.shape[0])
# Out:
# The total number of rows are 8108

# %%
df.head()
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727         ALARM CLOCK BAKELIKE RED        24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                  STARS GIFT TAPE        24
#
#            InvoiceDate  UnitPrice  CustomerID
# 0  2010-12-01 08:45:00       3.75     12583.0
# 1  2010-12-01 08:45:00       3.75     12583.0
# 2  2010-12-01 08:45:00       3.75     12583.0
# 3  2010-12-01 08:45:00       0.85     12583.0
# 4  2010-12-01 08:45:00       0.65     12583.0

# %%
basket = (
    df.groupby(['InvoiceNo', 'Description' ])['Quantity'].sum()
    .unstack().fillna(0).reset_index().set_index('InvoiceNo')

)

basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# ...

# %%
basket.describe()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# count                    387.000000                  387.000000
# mean                       0.868217                    0.310078
# std                        5.109242                    2.474110
# min                        0.000000                    0.000000
# 25%                        0.000000                    0.000000
# 50%                        0.000000                    0.000000
# 75%                        0.000000                    0.000000
# max                       48.000000                   20.000000
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# count                       387.000000                       387.000000
# mean                          0.005168                         0.062016
# std                           0.101666                         0.861544
# min                           0.000000                         0.000000
# ...

# %%
def encode_units(x):
  if x <= 0:
    return False
  if x >= 1:
    return True

basket_sets = basket.map(encode_units)
basket_sets.describe()
# Out:
# Description 10 COLOUR SPACEBOY PEN 12 COLOURED PARTY BALLOONS  \
# count                          387                        387
# unique                           2                          2
# top                          False                      False
# freq                           375                        381
#
# Description 12 EGG HOUSE PAINTED WOOD 12 MESSAGE CARDS WITH ENVELOPES  \
# count                             387                             387
# unique                              2                               2
# top                             False                           False
# freq                              386                             385
#
# Description 12 PENCIL SMALL TUBE WOODLAND 12 PENCILS SMALL TUBE RED RETROSPOT  \
# count                                 387                                 387
# unique                                  2                                   2
# ...

# %%
min_support = 1
metric = 'lift'
min_rules = 20
step = 0.01
min_threshold = 1
while True:
  frequent_itemsets = apriori(basket_sets , min_support = min_support , use_colnames = True)
  if frequent_itemsets.shape[0]> 0:
    rules = association_rules(frequent_itemsets , metric = metric , min_threshold = min_threshold)
  if frequent_itemsets.shape[0] > 0 and rules.shape[0] >= min_rules:
    break
  else:
    min_support -= step

# %%
print("The parameters are" , "min_support =" , min_support ,"mmetric =", metric ,  "min_rules=" ,min_rules , "number of frequent itemsets=" , frequent_itemsets.shape[0])
# Out:
# The parameters are min_support = 0.07999999999999925 mmetric = lift min_rules= 20 number of frequent itemsets= 41

# %%
rules
# Out:
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                          (ALARM CLOCK BAKELIKE RED)
# 2                          (PLASTERS IN TIN SPACEBOY)
# 3                     (PLASTERS IN TIN CIRCUS PARADE)
# 4                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 5                     (PLASTERS IN TIN CIRCUS PARADE)
# 6                          (PLASTERS IN TIN SPACEBOY)
# 7                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 8                (SET/20 RED RETROSPOT PAPER NAPKINS)
# 9                       (SET/6 RED SPOTTY PAPER CUPS)
# 10                    (SET/6 RED SPOTTY PAPER PLATES)
# 11               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 12                    (SET/6 RED SPOTTY PAPER PLATES)
# 13                      (SET/6 RED SPOTTY PAPER CUPS)
# 14  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 15  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# ...

# %%
sorted = rules.sort_values(by=['lift' , 'confidence'] , ascending=False).reset_index(drop=True)
sorted.head()
# Out:
#                                          antecedents  \
# 0                         (ALARM CLOCK BAKELIKE RED)
# 1                       (ALARM CLOCK BAKELIKE GREEN)
# 2  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 3                    (SET/6 RED SPOTTY PAPER PLATES)
# 4  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
#
#                                          consequents  antecedent support  \
# 0                       (ALARM CLOCK BAKELIKE GREEN)            0.095607
# 1                         (ALARM CLOCK BAKELIKE RED)            0.098191
# 2                    (SET/6 RED SPOTTY PAPER PLATES)            0.103359
# 3  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.129199
# 4                      (SET/6 RED SPOTTY PAPER CUPS)            0.103359
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.098191  0.080103    0.837838  8.532717               1.0
# ...

# %%
sorted.plot.scatter(x ='lift' , y = 'confidence', s = 3**(sorted['support']*30),title='Association Rules')
# Out:
# <Axes: title={'center': 'Association Rules'}, xlabel='lift', ylabel='confidence'>

# %%
s = [1.8**n for n in rules.lift]
rules.plot.scatter(x='support',
                   y='confidence',
                   title='Association Rules (dot proportional to Lift)',
                   s=s);
